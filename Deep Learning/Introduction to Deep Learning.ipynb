# %% [markdown]
# # Deep Learning
# - Deep learning is a subset of machine learning,

# %% [markdown]
# # Neural Network
# ![image.png](attachment:image.png)
#
#
# ### Hidden Layes
# - All input columns and output columns is call hidden layes
# - All layer having some neurons
# ### Active Function
# - each neurons having active functions
# ### Bias
# - each neurons has bias associated with it
# ### Fully connected layers ( dense layers )
# - each neuros of layer 1 is fully connected with each neurons of layer-1  ( using edges with weight )
# ### Edge
# - Each connection between the neurons are called edges and have some weight associated with it
# - Weight is speciy that how importat of neurons
# - All neurons are with same active function
#
#
# # Artificial Neural Network
# - Input is fade to to network from input layer this setup is called ANN
# - It is sequential process method

# %% [markdown]
# # Each Neuron in a neural network
# - Equation
# - ![image.png](attachment:image.png)
# ### Proceess
# - ![image-2.png](attachment:image-2.png)
# ### Example
# - (1.2 * 0.005) + (3.8 * 0.005) + (4.2 * 0.005) + 0.1
# - (0.006) + (0.019) + (0.021) + 0.1
#
# - = 0.146

# %% [markdown]
# # Neural Networks Phases
# - Feed Forword ( Forword Propogation )
# - Back Forword
#
# # Feed Forword
# - A feedforward neural network is a type of artificial neural network in which nodes’ connections do not form a loop.
# - Often referred to as a multi-layered network of neurons, feedforward neural networks are so named because all information flows in a forward manner only.
# - ![image.png](attachment:image.png)

# %% [markdown]
# ## Steps of FeedForword
# - Initialized all connection by random weight<br><br>
#
# - Step 1: A set of inputs enter the network through the input layer and are multiplied by their weights. <br><br>
#
# - Step 2: Each value is added to receive a summation of the weighted inputs. If the sum value exceeds the specified limit ( usually 0), the output usually settles at 1. If the value falls short of the threshold ( specified limit), the result will be -1.  <br> <br>
# - Step 3: A single-layer perceptron uses the concepts of machine learning for classification. It is a crucial model of a feedforward neural network. <br><br>
# - Step 4: The outputs of the neural network can then be compared with their predicted values with the help of the delta rule, thereby facilitating the network to optimize its weights through training to obtain output values with better accuracy. This process of training and learning generates a gradient descent.  <br><br>
# - Step 5: In multi-layered networks, updating weights are analogous and more specifically defined as backpropagation. Here, each hidden layer is modified to stay in tune with the output value generated by the final layer.  <br><br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Epoch
# - An epoch means training the neural network with all the training data for one cycle. In an epoch, we use all of the data exactly once. A forward pass and a backward pass together are counted as one pass:
# - ![image.png](attachment:image.png)

# %% [markdown]
# # back propgation(Back forward)
# - Grediant boosting algorthm
# - new weight = old weight(x) - Learning Rate * ( error / weight(x) )
#
# ![image.png](attachment:image.png)
# ## Chain Rule
# - the chian rule allow us to find the derivative of composite function
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Activation Function
# - decide weather a nueorn should be important for network or not
# - check weather nueron should be activate or not
# - is add non-linearity to the network
#
# ### 1. Binary step function
#    ![image.png](attachment:image.png)
#    ![image-2.png](attachment:image-2.png)
#
# ### 2. Liner Activation Function
#     - A straight line function where activation is proportional to input
#    ![image-3.png](attachment:image-3.png)
# ### 3. Non Liner activation function
#     - Allow Backpropogation because derivative function would be related to input ( 2x )
#     - Input pass through multiple layes
#
# ### 3.1 Sigmoid | Logistics Activation Function
# - Sigmoid takes a real value as input and outputs another value between 0 and 1.
# - It has a smooth gradient too.
# - The output of the activation function is always going to be in range (0,1) compared to (-inf, inf)
# ![image-4.png](attachment:image-4.png)
#
# ### 3.2 Tanh Function
# - Tanh squashes a real-valued number to the range [-1, 1].
# - It’s non-linear. But unlike Sigmoid, its output is zero-centered
# - ![image-5.png](attachment:image-5.png)
# - <strong>Tanh also has the vanishing gradient problem.</strong>
#
# ### 3.3 ReLU Function
# - A recent invention which stands for Rectified Linear Units.
# - The formula is deceptively simple: max(0,z). Despite its name and appearance,
# - It avoids and rectifies vanishing gradient problem.
# - it should only be used within hidden layers of a neural network model.
# - Dying ReLU problem :
#     - weight and bias are not updated
#     - and create dead nuerons which never be activate
#     - Solution is LeakyReLU
# -
# - ![image-7.png](attachment:image-7.png)
# -
# - ![image-6.png](attachment:image-6.png)
#
# ## 3.4 LeakyReLU Function
# - LeakyRelu is a variant of ReLU. Instead of being 0 when z<0, a leaky ReLU allows a small, non-zero
# - constant gradient α (Normally, α=0.01).
# -
# - ![image-9.png](attachment:image-9.png)
# -
# - ![image-8.png](attachment:image-8.png)
#
# ## 3.4 SoftMax Function
# - Multiple Classification
# - Softmax function calculates the probabilities distribution of the event over ‘n’ different events.
# - In general way of saying, this function will calculate the probabilities of each target class over all possible target classes.
# - Later the calculated probabilities will be helpful for determining the target class for the given inputs.
#
# ## Challenges in ANN
# - Vanishing -
# - Exploding
