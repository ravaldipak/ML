# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder

# %%
gender = ['male','female','male','female','male','female','male','female','female'];
gender_df = pd.DataFrame(gender,columns=["Gender"])

# %%
gender_df
# Out:
#    Gender
# 0    male
# 1  female
# 2    male
# 3  female
# 4    male
# 5  female
# 6    male
# 7  female
# 8  female

# %% [markdown]
# ### This is nominal catagory data

# %%
gender_df["Gender"] = gender_df["Gender"].map({'male':1,'female':0})

# %%
gender_df
# Out:
#    Gender
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
# 5       0
# 6       1
# 7       0
# 8       0

# %%
gender_df["maritial_status"] = ["married","married","unmarried","devorsed","unmarried","unmarried","married","devorsed","married"]

# %%
gender_df
# Out:
#    Gender maritial_status
# 0       1         married
# 1       0         married
# 2       1       unmarried
# 3       0        devorsed
# 4       1       unmarried
# 5       0       unmarried
# 6       1         married
# 7       0        devorsed
# 8       0         married

# %% [markdown]
# ## One & Hot

# %%
df1 = pd.get_dummies(gender_df["maritial_status"],drop_first=True);
df1
# Out:
#    married  unmarried
# 0        1          0
# 1        1          0
# 2        0          1
# 3        0          0
# 4        0          1
# 5        0          1
# 6        1          0
# 7        0          0
# 8        1          0

# %%
# contact df
gender_df = pd.concat([gender_df,df1],axis=1)
gender_df
# Out:
#    Gender maritial_status  married  unmarried
# 0       1         married        1          0
# 1       0         married        1          0
# 2       1       unmarried        0          1
# 3       0        devorsed        0          0
# 4       1       unmarried        0          1
# 5       0       unmarried        0          1
# 6       1         married        1          0
# 7       0        devorsed        0          0
# 8       0         married        1          0

# %%
gender_df = gender_df.drop(axis=1,columns=['maritial_status'])

# %%
gender_df
# Out:
#    Gender  married  unmarried
# 0       1        1          0
# 1       0        1          0
# 2       1        0          1
# 3       0        0          0
# 4       1        0          1
# 5       0        0          1
# 6       1        1          0
# 7       0        0          0
# 8       0        1          0

# %%
# plot the heatmap
corr = gender_df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Ordinal

# %%
df = gender_df

# %%
df["Grade"] = ["A","A","B","C","B","D","B","A","C"]

# %%
df
# Out:
#    Gender  married  unmarried Grade
# 0       1        1          0     A
# 1       0        1          0     A
# 2       1        0          1     B
# 3       0        0          0     C
# 4       1        0          1     B
# 5       0        0          1     D
# 6       1        1          0     B
# 7       0        0          0     A
# 8       0        1          0     C
