#   color: #000000;
# }
# #T_06842_row0_col26, #T_06842_row7_col59, #T_06842_row8_col38 {
#   background-color: #fad5db;
#   color: #000000;
# }
# #T_06842_row0_col34, #T_06842_row1_col43, #T_06842_row2_col80, #T_06842_row7_col4, #T_06842_row10_col0, #T_06842_row12_col19, #T_06842_row15_col67, #T_06842_row16_col26, #T_06842_row16_col59 {
#   background-colo

# %%
isnull = train.isnull().sum().sort_values(ascending=False).to_frame()
isnull.columns = ['How_many']
isnull['precentage'] = np.around(((isnull / len(train) * 100)[(isnull / len(train) * 100) != 0]), decimals=2)
isnull[isnull.How_many > 0].style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_846fd_row0_col0, #T_846fd_row0_col1 {
#   background-color: #ffc0cb;
#   color: #000000;
# }
# #T_846fd_row1_col0, #T_846fd_row1_col1 {
#   background-color: #ffc2cc;
#   color: #000000;
# }
# #T_846fd_row2_col0, #T_846fd_row2_col1 {
#   background-color: #fec3cd;
#   color: #000000;
# }
# #T_846fd_row3_col0, #T_846fd_row3_col1 {
#   background-color: #fdc9d2;
#   color: #000000;
# }
# #T_846fd_row4_col0, #T_846fd_row4_col1 {
#   background-color: #f9d9df;
#   color: #000000;
# }
# #T_846fd_row5_col0, #T_846fd_row5_col1 {
#   background-color: #f5e7ea;
#   color: #000000;
# }
# #T_846fd_row6_col0, #T_846fd_row6_col1, #T_846fd_row7_col0, #T_846fd_row7_col1, #T_846fd_row8_col0, #T_846fd_row8_col1, #T_846fd_row9_col0, #T_846fd_row9_col1, #T_846fd_row10_col0, #T_846fd_row10_col1 {
#   background-color: #f3edee;
#   color: #000000;
# }
# #T_846fd_row11_col0, #T_846fd_row11_col1, #T_846fd_row12_col0, #T_846fd_row12_col1, #T_846fd_row13_col0, #T_846fd_row13_col1, #T_846fd_row14_col0, #T_846fd_row14_col1, #T_846fd_row15_col0, #T_846fd_row15_col1 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_846fd_row16_col0, #T_846fd_row16_col1, #T_846fd_row17_col0, #T_846fd_row17_col1, #T_846fd_row18_col0, #T_846fd_row18_col1 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# </style>
# <table id="T_846fd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >How_many</th>
#       <th class="col_heading level0 col1" >precentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_846fd_level0_row0" class="row_heading level0 row0" >PoolQC</th>
#       <td id="T_846fd_row0_col0" class="data row0 col0" >1453</td>
#       <td id="T_846fd_row0_col1" class="data row0 col1" >99.520000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row1" class="row_heading level0 row1" >MiscFeature</th>
#       <td id="T_846fd_row1_col0" class="data row1 col0" >1406</td>
#       <td id="T_846fd_row1_col1" class="data row1 col1" >96.300000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row2" class="row_heading level0 row2" >Alley</th>
#       <td id="T_846fd_row2_col0" class="data row2 col0" >1369</td>
#       <td id="T_846fd_row2_col1" class="data row2 col1" >93.770000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row3" class="row_heading level0 row3" >Fence</th>
#       <td id="T_846fd_row3_col0" class="data row3 col0" >1179</td>
#       <td id="T_846fd_row3_col1" class="data row3 col1" >80.750000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row4" class="row_heading level0 row4" >FireplaceQu</th>
#       <td id="T_846fd_row4_col0" class="data row4 col0" >690</td>
#       <td id="T_846fd_row4_col1" class="data row4 col1" >47.260000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row5" class="row_heading level0 row5" >LotFrontage</th>
#       <td id="T_846fd_row5_col0" class="data row5 col0" >259</td>
#       <td id="T_846fd_row5_col1" class="data row5 col1" >17.740000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row6" class="row_heading level0 row6" >GarageYrBlt</th>
#       <td id="T_846fd_row6_col0" class="data row6 col0" >81</td>
#       <td id="T_846fd_row6_col1" class="data row6 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row7" class="row_heading level0 row7" >GarageCond</th>
#       <td id="T_846fd_row7_col0" class="data row7 col0" >81</td>
#       <td id="T_846fd_row7_col1" class="data row7 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row8" class="row_heading level0 row8" >GarageType</th>
#       <td id="T_846fd_row8_col0" class="data row8 col0" >81</td>
#       <td id="T_846fd_row8_col1" class="data row8 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row9" class="row_heading level0 row9" >GarageFinish</th>
#       <td id="T_846fd_row9_col0" class="data row9 col0" >81</td>
#       <td id="T_846fd_row9_col1" class="data row9 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row10" class="row_heading level0 row10" >GarageQual</th>
#       <td id="T_846fd_row10_col0" class="data row10 col0" >81</td>
#       <td id="T_846fd_row10_col1" class="data row10 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row11" class="row_heading level0 row11" >BsmtFinType2</th>
#       <td id="T_846fd_row11_col0" class="data row11 col0" >38</td>
#       <td id="T_846fd_row11_col1" class="data row11 col1" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row12" class="row_heading level0 row12" >BsmtExposure</th>
#       <td id="T_846fd_row12_col0" class="data row12 col0" >38</td>
#       <td id="T_846fd_row12_col1" class="data row12 col1" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row13" class="row_heading level0 row13" >BsmtQual</th>
#       <td id="T_846fd_row13_col0" class="data row13 col0" >37</td>
#       <td id="T_846fd_row13_col1" class="data row13 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row14" class="row_heading level0 row14" >BsmtCond</th>
#       <td id="T_846fd_row14_col0" class="data row14 col0" >37</td>
#       <td id="T_846fd_row14_col1" class="data row14 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row15" class="row_heading level0 row15" >BsmtFinType1</th>
#       <td id="T_846fd_row15_col0" class="data row15 col0" >37</td>
#       <td id="T_846fd_row15_col1" class="data row15 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row16" class="row_heading level0 row16" >MasVnrArea</th>
#       <td id="T_846fd_row16_col0" class="data row16 col0" >8</td>
#       <td id="T_846fd_row16_col1" class="data row16 col1" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row17" class="row_heading level0 row17" >MasVnrType</th>
#       <td id="T_846fd_row17_col0" class="data row17 col0" >8</td>
#       <td id="T_846fd_row17_col1" class="data row17 col1" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_846fd_level0_row18" class="row_heading level0 row18" >Electrical</th>
#       <td id="T_846fd_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_846fd_row18_col1" class="data row18 col1" >0.070000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### replace the null values in numeric columns with the mean of that column

# %% [markdown]
# #### LotFrontage column

# %%
train["LotFrontage"].isnull().sum()
# Out:
# 259

# %%
train['LotFrontage'].fillna(int(train['LotFrontage'].mean()), inplace=True)

# %%
train["LotFrontage"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### GarageYrBlt column

# %%
train["GarageYrBlt"].isnull().sum()
# Out:
# 81

# %%
train['GarageYrBlt'].fillna(int(train['GarageYrBlt'].mean()), inplace=True)

# %%
train["GarageYrBlt"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### drop null values in the columns that has a total number of missing data > 5

# %%
number_of_missing = train.isnull().sum().sort_values()
percent_of_missing = ((train.isnull().sum() / train.isnull().count())*100).sort_values()
missing_train_df = pd.concat([number_of_missing,  percent_of_missing], keys = ['total number of missing data', 'total percent of missing data'], axis = 1)
train = train.drop((missing_train_df[missing_train_df['total number of missing data'] > 5]).index, axis = 1)
train.isnull().sum().sort_values(ascending = False)
# Out:
# Electrical      1
# CentralAir      0
# 1stFlrSF        0
# 2ndFlrSF        0
# LowQualFinSF    0
#                ..
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# SalePrice       0
# Length: 65, dtype: int64

# %% [markdown]
# ### the columns that has <5 null values, we choose the most repeated value and fill the missing data with it

# %%
train['Electrical'].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
train['Electrical'].fillna(train['Electrical'].value_counts().index[0], inplace = True)

# %% [markdown]
# ## which feature has the maximum correlation with the Sale Price of the house?

# %%
max = 0
x=0
for i in train.select_dtypes(include=np.number).drop(['SalePrice'],axis=1).columns:
    if (train[i].corr(train['SalePrice'])) > max:
        max = train[i].corr(train['SalePrice'])
        x = i
print("The column which has the maximum correlation with the SalePrice is: {0}" .format(x))
# Out:
# The column which has the maximum correlation with the SalePrice is: OverallQual

# %% [markdown]
# ## Unique value in each columns

# %%
arr=[]
for i in train.columns:
    arr.append(len(train[i].value_counts()))
value_counts_df = pd.concat([pd.Series(train.columns), pd.Series(arr)], keys = ['column name', 'number of unique values in that column'], axis = 1)

value_counts_df
# Out:
#       column name  number of unique values in that column
# 0              Id                                    1460
# 1      MSSubClass                                      15
# 2        MSZoning                                       5
# 3     LotFrontage                                     110
# 4         LotArea                                    1073
# ..            ...                                     ...
# 60         MoSold                                      12
# 61         YrSold                                       5
# 62       SaleType                                       9
# 63  SaleCondition                                       6
# 64      SalePrice                                     663
#
# [65 rows x 2 columns]

# %%
value_counts_df.sort_values('number of unique values in that column').head(23)
# Out:
#      column name  number of unique values in that column
# 33    CentralAir                                       2
# 5         Street                                       2
# 8      Utilities                                       2
# 42      HalfBath                                       3
# 52    PavedDrive                                       3
# 40  BsmtHalfBath                                       3
# 10     LandSlope                                       3
# 45   KitchenQual                                       4
# 24     ExterQual                                       4
# 48    Fireplaces                                       4
# 39  BsmtFullBath                                       4
# 7    LandContour                                       4
# 6       LotShape                                       4
# 44  KitchenAbvGr                                       4
# 41      FullBath                                       4
# 61        YrSold                                       5
# 25     ExterCond                                       5
# 34    Electrical                                       5
# 32     HeatingQC                                       5
# 50    GarageCars                                       5
# 2       MSZoning                                       5
# 9      LotConfig                                       5
# 14      BldgType                                       5

# %% [markdown]
# ## what is the relation between Overall material and finish quality, sale price depending on Overall condition rating?

# %%
sns.lmplot(x='OverallQual', y='SalePrice', data=train ,hue='OverallCond',size=8)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## relation between grade (ground) living area square feet and Sale Price depending on general zoning

# %%
sns.lmplot(x='GrLivArea', y='SalePrice', data=train,col='MSZoning',size=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Univariate Analysis
# ### Numerical variables:

# %%
n_val = train.select_dtypes(exclude=['object']).drop(['MSSubClass'], axis=1).copy()
l=[]
for i in n_val:
  l.append(i)
print("Total no of numerical variables:",len(l))
# Out:
# Total no of numerical variables: 36

# %%
fig = plt.figure(figsize=(18,16))
for index,col in enumerate(n_val):
    plt.subplot(6,6,index+1)
    sns.distplot(n_val.loc[:,col].dropna(), kde=False,color='r')
fig.tight_layout(pad=1.0)

# %% [markdown]
# - From the given plots we can tell that certain numerical variables have only one kind of value:
#     - BsmtFitSF2
#     - LowQualFinSF
#     - BSMHalfBath
#     - KitchenAbvGr
#     - EnclosedPorch
#     - 3snPorch
#     - Screen Porch
#     - PoolArea
#     - MiscVal

# %% [markdown]
# ## Categorical Variables

# %%
c_val = train.select_dtypes(include=['object']).copy()
c_val['MSSubClass'] = train['MSSubClass']
print(c_val.columns)
l=[]
for i in c_val:
  l.append(i)
print("Total no of categorical variables:",len(l))
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'PavedDrive', 'SaleType', 'SaleCondition', 'MSSubClass'],
#       dtype='object')
# Total no of categorical variables: 29

# %%
fig = plt.figure(figsize=(18,20))
for index in range(len(c_val.columns)):
    plt.subplot(9,5,index+1)
    sns.countplot(x=c_val.iloc[:,index], data=c_val.dropna())
    plt.xticks(rotation=90)
fig.tight_layout(pad=1.2)

# %% [markdown]
# - From the given plots we can tell that certain categorical features have only one kind of value:
#
#     - Condition2
#     - Street
#     - RoofMatl
#     - Utilites
#     - Heating

# %% [markdown]
# # Bivariate Analysis:

# %%
plt.figure(figsize=(14,12))
correlation = n_val.corr()
sns.heatmap(correlation, mask = correlation <0.8, linewidth=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### From the given correlation matrix we can infer the highly correlated features:
#     - 1stfirSF AND TotalBsmtSf
#     - TotRmsAbvGrd AND GrLivArea
#     - GarageArea AND GarageCars

# %% [markdown]
# ### We need to find the numerical features which have high correlation to the target variable 'SalePrice'

# %%
nfeatures_corr = n_val.corr()['SalePrice'][:-1]
# nfeatures_corr[abs(nfeatures_corr)>0.5]
high_fealist = nfeatures_corr[abs(nfeatures_corr)> 0.5].sort_values(ascending=False)
print("HIGHLY CORRELATED FEATURES:\n")
print(high_fealist)
# Out:
# HIGHLY CORRELATED FEATURES:
#
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %% [markdown]
# ###  Finding the relation between the numerical features and the target variables:

# %%
fig = plt.figure(figsize=(20,20))
for index in range(len(n_val.columns)):
    plt.subplot(10,5,index+1)
    sns.scatterplot(x=n_val.iloc[:,index], y='SalePrice', data=n_val.dropna())
fig.tight_layout(pad=1.0)

# %% [markdown]
# #### From the above scatterplots for various features we can see that
#
#     - MoSold
#     - YrSold
#
# #### does not have any linear relationship with the target variable hence we can drop them

# %%
train.drop(['MoSold','YrSold'], axis=1, inplace=True)

# %%
sns.distplot(np.log(train['SalePrice']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>
