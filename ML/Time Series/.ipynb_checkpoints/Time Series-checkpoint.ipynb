# %% [markdown]
# # Time Series

# %% [markdown]
# - Time series is sequence of metric in recoreded over regular time intervals
#
# ## Time series Data
#
# - Anu data that has a time componenet involved in it is termed as a time series data
#
# ## Time series Analysis
#
# - Performing analysis on a time series data to find usefil insights and patterns in temed as time series analysis
#
# ## Time Series Forcasting
#
# - Forcasting means Predicting some values taht might occurs in future

# %% [markdown]
# ## Time series vs regression
# - Time Dependent
# - Seasonality trend
#
# X axis - Times <br>
# Y Axix - Values

# %% [markdown]
# ### Example : The Air Passengr Traffic Forecasting Problems
#
# - An airline company has the dataon the number of passengers that have travelled with them on particular route for the past few years. using this data, they want to see if they can foredast the number of passengers for the newxt twelve months
# <br>
# - How do you think this forecast would be benefcial to the company??
# <br>
#
# Decisions :
# - 1. What capacity aircraft should they use?
# - 2. When should they fly?
# - 3. How many air hostesses and pilotes do they needs?
# - 4. How much food should they shock in their inventory?

# %% [markdown]
# ## Components Of Time Series
# <br>
# <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 1. Level - Graph kya thi start thy che te position of "y"
#
# - 2. Trend
# - 3. Seasonality :
# - 4. Cyclicity : repeating pattern in data that repeates itself on irreguler basis
# - 5. Random Trends/Noise : Completely random fluctuation present in data

# %% [markdown]
# # Handling Meassing Values
# <br>
# - Mean Imputation <br>
# - Last observation carried Forwartd <br>
# - linear interpolation <br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
airpax_data = pd.read_csv("airline-passenger-traffic.csv",names=["Month","Passengers"])
airpax_data.head()
# Out:
#      Month  Passengers
# 0  1949-01       112.0
# 1  1949-02       118.0
# 2  1949-03       132.0
# 3  1949-04       129.0
# 4  1949-05       121.0

# %%
airpax_data['Month'] = pd.to_datetime(airpax_data['Month'],format='%Y-%m') #convert from string to datetime
airpax_data = airpax_data.set_index(['Month'])

# %%
# airpax_data.dropna(inplace=True)
airpax_data = airpax_data.fillna(airpax_data.bfill())

# %%
airpax_data.isnull().sum()
# Out:
# Passengers    0
# dtype: int64

# %%
airpax_data
# Out:
#             Passengers
# Month
# 1949-01-01       112.0
# 1949-02-01       118.0
# 1949-03-01       132.0
# 1949-04-01       129.0
# 1949-05-01       121.0
# ...                ...
# 1960-08-01       606.0
# 1960-09-01       508.0
# 1960-10-01       461.0
# 1960-11-01       390.0
# 1960-12-01       432.0
#
# [144 rows x 1 columns]

# %%
## plot graph
plt.xlabel('Date')
plt.ylabel('Number of air passengers')
plt.plot(airpax_data)

# %% [markdown]
# - From Graph to classifies this is "Trend" or "Seasonal" data

# %% [markdown]
# # Outlier detection

# %%
import seaborn as sns
fig = plt.subplots(figsize=(12, 2))
ax = sns.boxplot(x=airpax_data['Passengers'],whis=1.5)

# %%
fig = airpax_data.Passengers.hist(figsize = (12,4))

# %%
from pylab import rcParams
import statsmodels.api as sm

# %%
rcParams['figure.figsize'] = 12, 8
decomposition = sm.tsa.seasonal_decompose(airpax_data.Passengers, model='additive') # additive seasonal index
fig = decomposition.plot()
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(airpax_data.Passengers, model='multiplicative') # multiplicative seasonal index
fig = decomposition.plot()
plt.show()

# %% [markdown]
# # Simlpe smoothening technique
#
# ### 1. Naive Method
# ### 2. Simple average method
# ### 3. Moving average

# %% [markdown]
# # Exponential smoothing technique
#
# - is weighted moving average technique
# - all abesrvation are weighted equaly
# - (α) Alpha is capture the level
# - is not giving better result in trend

# %% [markdown]
# ### 1. Double Ecponential Smooting Technique</h3>
# - Hot's Expponential smoothing

# %% [markdown]
# ### 2. Triple Exponential smoothing
# - Seasonality, trend, and level measure krase
# - Gamma Perameter

# %% [markdown]
# #### Classification
# - Presisions
# - Recall
# - specification
#
# #### Regration :
# - RMSE ( Root Mean Squeard Error )
# - MAPE ( Mean Absolute Precentage Error )
