# %% [markdown]
# # Model Selection
# - Dependend on data distribution

# %% [markdown]
# 1. Model With High Bias
# 2. Model with High Variance
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Challange of model selection for machine learning

# %% [markdown]
# ## Genralization

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bias & variance Trade-Off

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Reduce Bias and variance

# %% [markdown]
# 1. Ragulerization
# 2. Resampling
#     - estimate the perfomance of model
#     - Methods
#         - Leave One Out Cross Validation ( LOOCV )
#         - K-Fold Cross Validation ( K=4 , 4 time irritate and 4 part equally splited )
#         -
